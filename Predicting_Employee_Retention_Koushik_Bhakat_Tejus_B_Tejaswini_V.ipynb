# %% [markdown]
# # **Predicting Employee Retention**

# %% [markdown]
# ### Objective
#
# The objective of this assignment is to develop a Logistic Regression model. You will be using this model to analyse and predict binary outcomes based on the input data. This assignment aims to enhance understanding of logistic regression, including its assumptions, implementation, and evaluation, to effectively classify and interpret data.

# %% [markdown]
# ### Business Objective
#
# A mid-sized technology company wants to improve its understanding of employee retention to foster a loyal and committed workforce. While the organization has traditionally focused on addressing turnover, it recognises the value of proactively identifying employees likely to stay and understanding the factors contributing to their loyalty.
#
#
# In this assignment you’ll be building a logistic regression model to predict the likelihood of employee retention based on the data such as demographic details, job satisfaction scores, performance metrics, and tenure. The aim is to provide the HR department with actionable insights to strengthen retention strategies, create a supportive work environment, and increase the overall stability and satisfaction of the workforce.

# %% [markdown]
# ## Assignment Tasks
#
# You need to perform the following steps to complete this assignment:
# 1. Data Understanding
# 2. Data Cleaning
# 3. Train Validation Split
# 4. EDA on training data
# 5. EDA on validation data [Optional]
# 6. Feature Engineering
# 7. Model Building
# 8. Prediction and Model Evaluation

# %% [markdown]
# ## Data Dictionary
#
# The data has 24 Columns and 74610 Rows. Following data dictionary provides the description for each column present in dataset:<br>
#
# <table>
#   <thead>
#     <tr>
#       <th>Column Name</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Employee ID</td>
#       <td>A unique identifier assigned to each employee.</td>
#     </tr>
#     <tr>
#       <td>Age</td>
#       <td>The age of the employee, ranging from 18 to 60 years.</td>
#     </tr>
#     <tr>
#       <td>Gender</td>
#       <td>The gender of the employee.</td>
#     </tr>
#     <tr>
#       <td>Years at Company</td>
#       <td>The number of years the employee has been working at the company.</td>
#     </tr>
#     <tr>
#       <td>Monthly Income</td>
#       <td>The monthly salary of the employee, in dollars.</td>
#     </tr>
#     <tr>
#       <td>Job Role</td>
#       <td>The department or role the employee works in, encoded into categories such as Finance, Healthcare, Technology, Education, and Media.</td>
#     </tr>
#     <tr>
#       <td>Work-Life Balance</td>
#       <td>The employee's perceived balance between work and personal life (Poor, Below Average, Good, Excellent).</td>
#     </tr>
#     <tr>
#       <td>Job Satisfaction</td>
#       <td>The employee's satisfaction with their job (Very Low, Low, Medium, High).</td>
#     </tr>
#     <tr>
#       <td>Performance Rating</td>
#       <td>The employee's performance rating (Low, Below Average, Average, High).</td>
#     </tr>
#     <tr>
#       <td>Number of Promotions</td>
#       <td>The total number of promotions the employee has received.</td>
#     </tr>
#      </tr>
#      <tr>
#       <td>Overtime</td>
#       <td>Number of overtime hours.</td>
#     </tr>
#     <tr>
#       <td>Distance from Home</td>
#       <td>The distance between the employee's home and workplace, in miles.</td>
#     </tr>
#     <tr>
#       <td>Education Level</td>
#       <td>The highest education level attained by the employee (High School, Associate Degree, Bachelor’s Degree, Master’s Degree, PhD).</td>
#     </tr>
#     <tr>
#       <td>Marital Status</td>
#       <td>The marital status of the employee (Divorced, Married, Single).</td>
#     </tr>
#      <tr>
#       <td>Number of Dependents</td>
#       <td>Number of dependents the employee has.</td>
#     </tr>
#     <tr>
#       <td>Job Level</td>
#       <td>The job level of the employee (Entry, Mid, Senior).</td>
#     </tr>
#     <tr>
#       <td>Company Size</td>
#       <td>The size of the company the employee works for (Small, Medium, Large).</td>
#     </tr>
#     <tr>
#       <td>Company Tenure (In Months)</td>
#       <td>The total number of years the employee has been working in the industry.</td>
#     </tr>
#     <tr>
#       <td>Remote Work</td>
#       <td>Whether the employee works remotely (Yes or No).</td>
#     </tr>
#     <tr>
#       <td>Leadership Opportunities</td>
#       <td>Whether the employee has leadership opportunities (Yes or No).</td>
#     </tr>
#     <tr>
#       <td>Innovation Opportunities</td>
#       <td>Whether the employee has opportunities for innovation (Yes or No).</td>
#     </tr>
#     <tr>
#       <td>Company Reputation</td>
#       <td>The employee's perception of the company's reputation (Very Poor, Poor, Good, Excellent).</td>
#     </tr>
#     <tr>
#       <td>Employee Recognition</td>
#       <td>The level of recognition the employee receives(Very Low, Low, Medium, High).</td>
#     </tr>
#     <tr>
#       <td>Attrition</td>
#       <td>Whether the employee has left the company.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **1. Data Understanding**
#
# In this step, load the dataset and check basic statistics of the data, including preview of data, dimension of data, column descriptions and data types.

# %% [markdown]
# ### **1.0 Import Libraries**

# %%
# Supress unnecessary warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Import the libraries
import numpy as np
import pandas as pd

# %% [markdown]
# ### **1.1 Load the Data**

# %%
# Load the dataset
df = pd.read_csv("Employee_data.csv")

# %%
# Check the first few entries
df.head(20)
# Out:
#     Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0          8410   31    Male                19   Education            5390
# 1         64756   59  Female                 4       Media            5534
# 2         30257   24  Female                10  Healthcare            8159
# 3         65791   36  Female                 7   Education            3989
# 4         65026   56    Male                41   Education            4821
# 5         24368   38  Female                 3  Technology            9977
# 6         64970   47    Male                23   Education            3681
# 7         36999   48    Male                16     Finance           11223
# 8         32714   57    Male                44   Education            3773
# 9         15944   24  Female                 1  Healthcare            7319
# 10        29972   30  Female                12   Education            5443
# ...

# %%
# Inspect the shape of the dataset
df.shape
# Out:
# (74610, 24)

# %%
# Inspect the different columns in the dataset
df.columns
# Out:
# Index(['Employee ID', 'Age', 'Gender', 'Years at Company', 'Job Role',
#        'Monthly Income', 'Work-Life Balance', 'Job Satisfaction',
#        'Performance Rating', 'Number of Promotions', 'Overtime',
#        'Distance from Home', 'Education Level', 'Marital Status',
#        'Number of Dependents', 'Job Level', 'Company Size',
#        'Company Tenure (In Months)', 'Remote Work', 'Leadership Opportunities',
#        'Innovation Opportunities', 'Company Reputation',
#        'Employee Recognition', 'Attrition'],
#       dtype='object')

# %% [markdown]
# ### **1.2 Check the basic statistics**

# %%
# Check the summary of the dataset
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74610 entries, 0 to 74609
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee ID                 74610 non-null  int64
#  1   Age                         74610 non-null  int64
#  2   Gender                      74610 non-null  object
#  3   Years at Company            74610 non-null  int64
#  4   Job Role                    74610 non-null  object
#  5   Monthly Income              74610 non-null  int64
#  6   Work-Life Balance           74610 non-null  object
#  7   Job Satisfaction            74610 non-null  object
#  8   Performance Rating          74610 non-null  object
#  9   Number of Promotions        74610 non-null  int64
#  10  Overtime                    74610 non-null  object
#  11  Distance from Home          72698 non-null  float64
#  12  Education Level             74610 non-null  object
# ...

# %% [markdown]
# ### **1.3 Check the data type of columns**

# %%
# Check the info to see the types of the feature variables and the null values present
df.dtypes
# Out:
# Employee ID                     int64
# Age                             int64
# Gender                         object
# Years at Company                int64
# Job Role                       object
# Monthly Income                  int64
# Work-Life Balance              object
# Job Satisfaction               object
# Performance Rating             object
# Number of Promotions            int64
# Overtime                       object
# Distance from Home            float64
# Education Level                object
# Marital Status                 object
# Number of Dependents            int64
# Job Level                      object
# Company Size                   object
# Company Tenure (In Months)    float64
# Remote Work                    object
# Leadership Opportunities       object
# Innovation Opportunities       object
# Company Reputation             object
# Employee Recognition           object
# Attrition                      object
# dtype: object

# %% [markdown]
# ## **2. Data Cleaning** <font color = red>[15 marks]</font>

# %% [markdown]
# ### **2.1 Handle the missing values** <font color = red>[10 marks]</font>

# %% [markdown]
# 2.1.1 Check the number of missing values <font color="red">[2 Mark]</font>

# %%
# Check the number of missing values in each column
df.isnull().sum()
# Out:
# Employee ID                      0
# Age                              0
# Gender                           0
# Years at Company                 0
# Job Role                         0
# Monthly Income                   0
# Work-Life Balance                0
# Job Satisfaction                 0
# Performance Rating               0
# Number of Promotions             0
# Overtime                         0
# Distance from Home            1912
# Education Level                  0
# Marital Status                   0
# Number of Dependents             0
# Job Level                        0
# Company Size                     0
# Company Tenure (In Months)    2413
# Remote Work                      0
# Leadership Opportunities         0
# Innovation Opportunities         0
# Company Reputation               0
# Employee Recognition             0
# Attrition                        0
# dtype: int64

# %% [markdown]
# 2.1.2 Check the percentage of missing values <font color="red">[2 Marks]</font>

# %%
# Check the percentage of missing values in each column
missing_percentage = (df.isnull().sum()/len(df))*100
missing_percentage
# Out:
# Employee ID                   0.000000
# Age                           0.000000
# Gender                        0.000000
# Years at Company              0.000000
# Job Role                      0.000000
# Monthly Income                0.000000
# Work-Life Balance             0.000000
# Job Satisfaction              0.000000
# Performance Rating            0.000000
# Number of Promotions          0.000000
# Overtime                      0.000000
# Distance from Home            2.562659
# Education Level               0.000000
# Marital Status                0.000000
# Number of Dependents          0.000000
# Job Level                     0.000000
# Company Size                  0.000000
# Company Tenure (In Months)    3.234151
# Remote Work                   0.000000
# Leadership Opportunities      0.000000
# Innovation Opportunities      0.000000
# Company Reputation            0.000000
# Employee Recognition          0.000000
# Attrition                     0.000000
# ...

# %% [markdown]
# 2.1.3 Handle rows with missing values <font color="red">[4 Marks]</font>

# %%
# Handle the missing value rows in the column
df_cleaned = df.dropna()

# Check shape after removing missing values
print("\n Shape after dropping missing values:", df_cleaned.shape)
# Out:
#  Shape after dropping missing values: (70635, 24)

# %%
df_cleaned = df_cleaned.dropna(subset=['Distance from Home', 'Company Tenure (In Months)'])

# %% [markdown]
# 2.1.4 Check percentage of remaning data after missing values are removed <font color="red">[2 Mark]</font>

# %%
# Check the percentage of remaining data after missing values are removed
missing_percentage = (df_cleaned.isnull().sum()/len(df_cleaned))*100
missing_percentage
# Out:
# Employee ID                   0.0
# Age                           0.0
# Gender                        0.0
# Years at Company              0.0
# Job Role                      0.0
# Monthly Income                0.0
# Work-Life Balance             0.0
# Job Satisfaction              0.0
# Performance Rating            0.0
# Number of Promotions          0.0
# Overtime                      0.0
# Distance from Home            0.0
# Education Level               0.0
# Marital Status                0.0
# Number of Dependents          0.0
# Job Level                     0.0
# Company Size                  0.0
# Company Tenure (In Months)    0.0
# Remote Work                   0.0
# Leadership Opportunities      0.0
# Innovation Opportunities      0.0
# Company Reputation            0.0
# Employee Recognition          0.0
# Attrition                     0.0
# dtype: float64

# %% [markdown]
# ### **2.2 Identify and handle redundant values within categorical columns (if any)** <font color = red>[3 marks]</font>

# %% [markdown]
# Examine the categorical columns to determine if any value or column needs to be treated

# %%
# Write a function to display the categorical columns with their unique values and check for redundant values
# Step 1: Define function to explore categorical columns
def examine_categorical_columns(dataframe):
    categorical_cols = dataframe.select_dtypes(include='object').columns
    for col in categorical_cols:
        print(f"\n Column: {col}")
        print("Unique values:", dataframe[col].unique())
        print("Value counts:\n", dataframe[col].value_counts())

# Step 2: Call the function on your cleaned data
examine_categorical_columns(df_cleaned)
# Out:
#  Column: Gender
# Unique values: ['Male' 'Female']
# Value counts:
#  Gender
# Male      38700
# Female    31935
# Name: count, dtype: int64
#
#  Column: Job Role
# Unique values: ['Education' 'Media' 'Healthcare' 'Technology' 'Finance']
# Value counts:
#  Job Role
# Technology    18340
# Healthcare    16207
# Education     14813
# Media         11346
# Finance        9929
# Name: count, dtype: int64
#
#  Column: Work-Life Balance
# Unique values: ['Excellent' 'Poor' 'Good' 'Fair']
# Value counts:
#  Work-Life Balance
# Good         26683
# Fair         21402
# Excellent    12740
# Poor          9810
# Name: count, dtype: int64
#
#  Column: Job Satisfaction
# Unique values: ['Medium' 'High' 'Very High' 'Low']
# Value counts:
#  Job Satisfaction
# High         35332
# Very High    14283
# Medium       13954
# Low           7066
# Name: count, dtype: int64
#
#  Column: Performance Rating
# Unique values: ['Average' 'Low' 'High' 'Below Average']
# Value counts:
#  Performance Rating
# ...

# %%
# Check the data
df_cleaned.isnull().sum()
# Out:
# Employee ID                   0
# Age                           0
# Gender                        0
# Years at Company              0
# Job Role                      0
# Monthly Income                0
# Work-Life Balance             0
# Job Satisfaction              0
# Performance Rating            0
# Number of Promotions          0
# Overtime                      0
# Distance from Home            0
# Education Level               0
# Marital Status                0
# Number of Dependents          0
# Job Level                     0
# Company Size                  0
# Company Tenure (In Months)    0
# Remote Work                   0
# Leadership Opportunities      0
# Innovation Opportunities      0
# Company Reputation            0
# Employee Recognition          0
# Attrition                     0
# dtype: int64

# %% [markdown]
# ### **2.3 Drop redundant columns** <font color = red>[2 marks]</font>

# %%
# Drop redundant columns which are not required for modelling
# 'Employee ID' is a unique identifier and 'Job Role' is likely replaced by other categorical variables
df_cleaned = df.drop(columns=['Employee ID', 'Job Role'])

# View remaining columns
print("Remaining columns after dropping redundant ones:")
print(df_cleaned.columns.tolist())
# Out:
# Remaining columns after dropping redundant ones:
# ['Age', 'Gender', 'Years at Company', 'Monthly Income', 'Work-Life Balance', 'Job Satisfaction', 'Performance Rating', 'Number of Promotions', 'Overtime', 'Distance from Home', 'Education Level', 'Marital Status', 'Number of Dependents', 'Job Level', 'Company Size', 'Company Tenure (In Months)', 'Remote Work', 'Leadership Opportunities', 'Innovation Opportunities', 'Company Reputation', 'Employee Recognition', 'Attrition']

# %%
# Check first few rows of data
df_cleaned.isnull().sum()
# Out:
# Age                              0
# Gender                           0
# Years at Company                 0
# Monthly Income                   0
# Work-Life Balance                0
# Job Satisfaction                 0
# Performance Rating               0
# Number of Promotions             0
# Overtime                         0
# Distance from Home            1912
# Education Level                  0
# Marital Status                   0
# Number of Dependents             0
# Job Level                        0
# Company Size                     0
# Company Tenure (In Months)    2413
# Remote Work                      0
# Leadership Opportunities         0
# Innovation Opportunities         0
# Company Reputation               0
# Employee Recognition             0
# Attrition                        0
# dtype: int64

# %% [markdown]
# ## **3. Train-Validation Split** <font color = red>[5 marks]</font>

# %% [markdown]
# ### **3.1 Import required libraries**

# %%
# Import Train Test Split
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### **3.2 Define feature and target variables** <font color = red>[2 Mark]</font>

# %%
# Put all the feature variables in X
# Assuming df_cleaned already has 'Attrition' as the target column
X = df_cleaned.drop(columns=['Attrition'])

# Show the shape and column names in X
print("Shape of X:", X.shape)
print("Feature columns in X:")
print(X.columns.tolist())
# Out:
# Shape of X: (74610, 21)
# Feature columns in X:
# ['Age', 'Gender', 'Years at Company', 'Monthly Income', 'Work-Life Balance', 'Job Satisfaction', 'Performance Rating', 'Number of Promotions', 'Overtime', 'Distance from Home', 'Education Level', 'Marital Status', 'Number of Dependents', 'Job Level', 'Company Size', 'Company Tenure (In Months)', 'Remote Work', 'Leadership Opportunities', 'Innovation Opportunities', 'Company Reputation', 'Employee Recognition']

# %% [markdown]
# ### **3.3 Split the data** <font color="red">[3 Marks]</font>

# %%
# Split the data into 70% train data and 30% validation data
from sklearn.model_selection import train_test_split

# Define target variable
y = df_cleaned['Attrition']  # Binary target: 0 = Stayed, 1 = Left

# Split the data
X_train, X_validation, y_train, y_validation = train_test_split(
    X, y, test_size=0.30, random_state=42, stratify=y  # stratify ensures class distribution is maintained
)

# Show the shape of splits
print("Training data shape:", X_train.shape)
print("Validation data shape:", X_validation.shape)
# Out:
# Training data shape: (52227, 21)
# Validation data shape: (22383, 21)

# %% [markdown]
# ## **4. EDA on training data** <font color = red>[20 marks]</font>

# %% [markdown]
# ### **4.1 Perform univariate analysis** <font color = red>[6 marks]</font>

# %% [markdown]
# Perform univariate analysis on training data for all the numerical columns.

# %% [markdown]
# 4.1.1 Select numerical columns from training data <font color = "red">[1 Mark]</font>

# %%
# Select numerical columns

numerical_columns = X_train.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Print the list
print("Numerical columns in training data:")
print(numerical_columns)
# Out:
# Numerical columns in training data:
# ['Age', 'Years at Company', 'Monthly Income', 'Number of Promotions', 'Distance from Home', 'Number of Dependents', 'Company Tenure (In Months)']

# %% [markdown]
# 4.1.2 Plot distribution of numerical columns <font color = "red">[5 Marks]</font>

# %%
# Plot all the numerical columns to understand their distribution
import matplotlib.pyplot as plt
# List of numerical columns from X_train
numerical_columns = X_train.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Set up plot grid
num_cols = len(numerical_columns)
plt.figure(figsize=(18, 12))

# Plot histograms for each numerical column
for i, col in enumerate(numerical_columns):
    plt.subplot((num_cols + 2) // 3, 3, i + 1)
    X_train[col].hist(bins=30, edgecolor='black')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **4.2 Perform correlation analysis** <font color="red">[4 Marks]</font>

# %% [markdown]
# Check the correlation among different numerical variables.

# %%
# Create correlation matrix for numerical columns
import seaborn as sns
# Select numerical columns
numerical_columns = X_train.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Compute correlation matrix
correlation_matrix_numerical = X_train[numerical_columns].corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix_numerical, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix for Numerical Columns")
plt.show()

# %%
# Check the shape and data types in X_train

print("Shape of X_train:", X_train.shape)

# Check data types of each column
print("\nData types in X_train:")
print(X_train.dtypes)
# Out:
# Shape of X_train: (52227, 21)
#
# Data types in X_train:
# Age                             int64
# Gender                         object
# Years at Company                int64
# Monthly Income                  int64
# Work-Life Balance              object
# Job Satisfaction               object
# Performance Rating             object
# Number of Promotions            int64
# Overtime                       object
# Distance from Home            float64
# Education Level                object
# Marital Status                 object
# Number of Dependents            int64
# Job Level                      object
# Company Size                   object
# Company Tenure (In Months)    float64
# Remote Work                    object
# Leadership Opportunities       object
# Innovation Opportunities       object
# Company Reputation             object
# Employee Recognition           object
# dtype: object

# %% [markdown]
# ### **4.3 Check class balance** <font color="red">[2 Marks]</font>

# %% [markdown]
# Check the distribution of target variable in training set to check class balance.

# %%
# Plot a bar chart to check class balance

# Plot class balance in y_train
plt.figure(figsize=(6, 4))
y_train.value_counts().plot(kind='bar', color=['skyblue', 'salmon'], edgecolor='black')
plt.title('Class Balance in Training Data')
plt.xlabel('Attrition (0 = Stayed, 1 = Left)')
plt.ylabel('Number of Employees')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **4.4 Perform bivariate analysis** <font color="red">[8 Marks]</font>

# %% [markdown]
# Perform bivariate analysis on training data between all the categorical columns and target variable to  analyse how the categorical variables influence the target variable.

# %%
# Plot distribution for each categorical column with target variable
# Select categorical columns from X_train
categorical_columns = X_train.select_dtypes(include='object').columns.tolist()

# Set the plot grid
n_cols = 3
n_rows = (len(categorical_columns) + n_cols - 1) // n_cols
plt.figure(figsize=(n_cols * 6, n_rows * 4))

# Plot countplots for each categorical variable with hue as target
for i, col in enumerate(categorical_columns):
    plt.subplot(n_rows, n_cols, i + 1)
    sns.countplot(data=pd.concat([X_train, y_train], axis=1), x=col, hue='Attrition')
    plt.title(f'{col} vs Attrition')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **5. EDA on validation data** <font color = red>[OPTIONAL]</font>

# %% [markdown]
# ### **5.1 Perform univariate analysis**

# %% [markdown]
# Perform univariate analysis on validation data for all the numerical columns.

# %% [markdown]
# 5.1.1 Select numerical columns from validation data

# %%
# Select numerical columns

# %% [markdown]
# 5.1.2 Plot distribution of numerical columns

# %%
# Plot all the numerical columns to understand their distribution

# %% [markdown]
# ### **5.2 Perform correlation analysis**

# %% [markdown]
# Check the correlation among different numerical variables.

# %%
# Create correlation matrix for numerical columns

# Plot Heatmap of the correlation matrix

# %% [markdown]
# ### **5.3 Check class balance**

# %% [markdown]
# Check the distribution of target variable in validation data to check class balance.

# %%
# Plot a bar chart to check class balance

# %% [markdown]
# ### **5.4 Perform bivariate analysis**

# %% [markdown]
# Perform bivariate analysis on validation data between all the categorical columns and target variable to analyse how the categorical variables influence the target variable.

# %%
# Plot distribution for each categorical column with target variable

# %% [markdown]
# ## **6. Feature Engineering** <font color = red>[20 marks]</font>

# %% [markdown]
# ### **6.1 Dummy variable creation** <font color = red>[15 marks]</font>
#
#
# The next step is to deal with the categorical variables present in the data.

# %% [markdown]
# 6.1.1 Identify categorical columns where dummy variables are required <font color="red">[1 Mark]</font>

# %%
# Check the categorical columns
categorical_columns_for_dummies = X.select_dtypes(include='object').columns.tolist()

# Print the list
print("Categorical columns requiring dummy variable creation:")
print(categorical_columns_for_dummies)
# Out:
# Categorical columns requiring dummy variable creation:
# ['Gender', 'Work-Life Balance', 'Job Satisfaction', 'Performance Rating', 'Overtime', 'Education Level', 'Marital Status', 'Job Level', 'Company Size', 'Remote Work', 'Leadership Opportunities', 'Innovation Opportunities', 'Company Reputation', 'Employee Recognition']

# %% [markdown]
# 6.1.2 Create dummy variables for independent columns in training set <font color="red">[3 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for independent columns

# Create dummy variables for categorical columns using one-hot encoding
X_encoded = pd.get_dummies(X, columns=categorical_columns_for_dummies, drop_first=True)

# Check the new shape and a sample of encoded data
print("Shape after encoding:", X_encoded.shape)
print("\nSample of encoded features:")
print(X_encoded.head())
# Out:
# Shape after encoding: (74610, 37)
#
# Sample of encoded features:
#    Age  Years at Company  Monthly Income  Number of Promotions  \
# 0   31                19            5390                     2
# 1   59                 4            5534                     3
# 2   24                10            8159                     0
# 3   36                 7            3989                     1
# 4   56                41            4821                     0
#
#    Distance from Home  Number of Dependents  Company Tenure (In Months)  \
# 0                22.0                     0                        89.0
# 1                21.0                     3                        21.0
# 2                11.0                     3                        74.0
# 3                27.0                     2                        50.0
# 4                71.0                     0                        68.0
#
#    Gender_Male  Work-Life Balance_Fair  Work-Life Balance_Good  ...  \
# ...

# %% [markdown]
# Now, drop the original categorical columns and check the DataFrame

# %%
# Drop the original categorical columns and check the DataFrame
# Drop original categorical columns (only needed if get_dummies was used without 'columns=')
X_dropped = X.drop(columns=categorical_columns_for_dummies)

# Check the resulting DataFrame
print("Shape after dropping categorical columns:", X_dropped.shape)
print("\nPreview of the DataFrame:")
print(X_dropped.head())
# Out:
# Shape after dropping categorical columns: (74610, 7)
#
# Preview of the DataFrame:
#    Age  Years at Company  Monthly Income  Number of Promotions  \
# 0   31                19            5390                     2
# 1   59                 4            5534                     3
# 2   24                10            8159                     0
# 3   36                 7            3989                     1
# 4   56                41            4821                     0
#
#    Distance from Home  Number of Dependents  Company Tenure (In Months)
# 0                22.0                     0                        89.0
# 1                21.0                     3                        21.0
# 2                11.0                     3                        74.0
# 3                27.0                     2                        50.0
# 4                71.0                     0                        68.0

# %% [markdown]
# 6.1.3 Create dummy variables for independent columns in validation set <font color="red">[3 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for independent columns
#Create dummy variables using one-hot encoding
X_dummies = pd.get_dummies(X[categorical_columns], drop_first=True)

#Drop original categorical columns from X
X_numeric = X.drop(columns=categorical_columns)

#Combine numeric data with dummy variables
X_master = pd.concat([X_numeric, X_dummies], axis=1)

#View the final DataFrame
print("Shape of master DataFrame with dummies:", X_master.shape)
print("\nPreview of the master DataFrame:")
print(X_master.head())
# Out:
# Shape of master DataFrame with dummies: (74610, 37)
#
# Preview of the master DataFrame:
#    Age  Years at Company  Monthly Income  Number of Promotions  \
# 0   31                19            5390                     2
# 1   59                 4            5534                     3
# 2   24                10            8159                     0
# 3   36                 7            3989                     1
# 4   56                41            4821                     0
#
#    Distance from Home  Number of Dependents  Company Tenure (In Months)  \
# 0                22.0                     0                        89.0
# 1                21.0                     3                        21.0
# 2                11.0                     3                        74.0
# 3                27.0                     2                        50.0
# 4                71.0                     0                        68.0
#
# ...

# %% [markdown]
# Now, drop the original categorical columns and check the DataFrame

# %%
# Drop categorical columns and check the DataFrame
# Step 1: Identify categorical columns
categorical_columns = X.select_dtypes(include='object').columns.tolist()

# Step 2: Drop categorical columns
X_without_categoricals = X.drop(columns=categorical_columns)

# Step 3: Check the updated DataFrame
print("Shape after dropping categorical columns:", X_without_categoricals.shape)
print("\nPreview of DataFrame without categorical columns:")
print(X_without_categoricals.head())
# Out:
# Shape after dropping categorical columns: (74610, 7)
#
# Preview of DataFrame without categorical columns:
#    Age  Years at Company  Monthly Income  Number of Promotions  \
# 0   31                19            5390                     2
# 1   59                 4            5534                     3
# 2   24                10            8159                     0
# 3   36                 7            3989                     1
# 4   56                41            4821                     0
#
#    Distance from Home  Number of Dependents  Company Tenure (In Months)
# 0                22.0                     0                        89.0
# 1                21.0                     3                        21.0
# 2                11.0                     3                        74.0
# 3                27.0                     2                        50.0
# 4                71.0                     0                        68.0

# %% [markdown]
# 6.1.4 Create DataFrame for dependent column in both training and validation set <font color = "red">[1 Mark]</font>

# %%
# Convert y_train and y_validation to DataFrame to create dummy variables

y_train_df = pd.DataFrame(y_train, columns=['Attrition'])
y_validation_df = pd.DataFrame(y_validation, columns=['Attrition'])

# View the first few rows to confirm
print("y_train_df:")
print(y_train_df.head())

print("\ny_validation_df:")
print(y_validation_df.head())
# Out:
# y_train_df:
#       Attrition
# 20940    Stayed
# 17495      Left
# 28404      Left
# 70914    Stayed
# 56430    Stayed
#
# y_validation_df:
#       Attrition
# 61298      Left
# 46813    Stayed
# 37033      Left
# 41834    Stayed
# 25905    Stayed

# %% [markdown]
# 6.1.5 Create dummy variables for dependent column in training set <font color="red">[3 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for dependent column
# Convert y_train to DataFrame (if not already)
y_train_df = pd.DataFrame(y_train, columns=['Attrition'])

# Create dummy variables for the target column
y_train_dummies = pd.get_dummies(y_train_df['Attrition'], drop_first=True)

# View the dummy variable DataFrame
print("Dummy variables for y_train (Attrition):")
print(y_train_dummies.head())
# Out:
# Dummy variables for y_train (Attrition):
#        Stayed
# 20940    True
# 17495   False
# 28404   False
# 70914    True
# 56430    True

# %% [markdown]
# 6.1.6 Create dummy variable for dependent column in validation set <font color = "red">[3 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for dependent column
# Convert y_validation to DataFrame (if not already)
y_validation_df = pd.DataFrame(y_validation, columns=['Attrition'])

# Create dummy variables for the target column
y_validation_dummies = pd.get_dummies(y_validation_df['Attrition'], drop_first=True)

# View the dummy variable DataFrame
print("Dummy variables for y_validation (Attrition):")
print(y_validation_dummies.head())
# Out:
# Dummy variables for y_validation (Attrition):
#        Stayed
# 61298   False
# 46813    True
# 37033   False
# 41834    True
# 25905    True

# %% [markdown]
# 6.1.7 Drop redundant columns <font color="red">[1 Mark]</font>

# %%
# Drop redundant columns from both train and validation
# List of redundant columns to drop (example)
redundant_columns = ['Employee ID', 'Job Role']  # adjust as needed for your dataset

# Drop from both X_train and X_validation (only if these columns exist)
X_train = X_train.drop(columns=[col for col in redundant_columns if col in X_train.columns])
X_validation = X_validation.drop(columns=[col for col in redundant_columns if col in X_validation.columns])

# Confirm changes
print("X_train shape after dropping redundant columns:", X_train.shape)
print("X_validation shape after dropping redundant columns:", X_validation.shape)
# Out:
# X_train shape after dropping redundant columns: (52227, 21)
# X_validation shape after dropping redundant columns: (22383, 21)

# %% [markdown]
# ### **6.2 Feature scaling** <font color = red>[5 marks]</font>
#
# Apply feature scaling to the numeric columns to bring them to a common range and ensure consistent scaling.

# %% [markdown]
# 6.2.1 Import required libraries <font color="red">[1 Mark]</font>

# %%
# Import the necessary scaling tool from scikit-learn
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# 6.2.2 Scale the numerical features <font color="red">[4 Marks]</font>

# %%
# Scale the numeric features present in the training set
from sklearn.preprocessing import StandardScaler

# Step 1: Identify numeric columns
numeric_columns = X_train.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Step 2: Initialize the scaler
scaler = StandardScaler()

# Step 3: Fit on training data and transform both train and validation sets
X_train[numeric_columns] = scaler.fit_transform(X_train[numeric_columns])
X_validation[numeric_columns] = scaler.transform(X_validation[numeric_columns])

# Step 4: Confirm scaling worked
print("First 5 rows of scaled training data:")
print(X_train[numeric_columns].head())
# Out:
# First 5 rows of scaled training data:
#             Age  Years at Company  Monthly Income  Number of Promotions  \
# 20940 -1.127561         -1.308255       -1.204700              1.169352
# 17495 -1.044579         -0.240890        0.864966             -0.836255
# 28404 -0.297739          0.292793       -0.741193             -0.836255
# 70914 -1.459489         -0.596678        0.349660             -0.836255
# 56430  1.195939          0.737529       -0.510974              0.166548
#
#        Distance from Home  Number of Dependents  Company Tenure (In Months)
# 20940           -1.545883              2.116214                    0.879684
# 17495           -1.265290             -1.047331                    1.076379
# 28404           -1.405587              0.850796                   -0.300484
# 70914           -0.002623              2.116214                   -1.559330
# 56430           -1.300364             -1.047331                    0.919023

# %% [markdown]
# ## **7. Model Building** <font color = red>[40 marks]</font>

# %% [markdown]
# ### **7.1 Feature selection** <font color = red>[5 marks]</font>
#
# As there are a lot of variables present in the data, Recursive Feature Elimination (RFE) will be used to select the most influential features for building the model.

# %% [markdown]
# 7.1.1 Import required libraries <font color="red">[1 Mark]</font>

# %%
# Import 'LogisticRegression' and create a LogisticRegression object
from sklearn.linear_model import LogisticRegression

# Create LogisticRegression object
logreg_model = LogisticRegression(random_state=42, max_iter=1000)

# View the model
print(logreg_model)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %% [markdown]
# 7.1.2 Import RFE  and select 15 variables <font color="red">[3 Mark]</font>

# %%
# Combine training features and target again if necessary
X_train_encoded = pd.get_dummies(X_train, drop_first=True)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# Step 2: Drop irrelevant columns
df.drop(columns=['Employee ID', 'Job Role'], inplace=True)

# Step 3: Convert target column to binary
df['Attrition'] = df['Attrition'].map({'Stayed': 0, 'Left': 1})

# Step 4: Separate features and target (now, not later)
target = df['Attrition']
df_features = df.drop(columns=['Attrition'])

# Step 5: Identify numeric and categorical columns
num_cols = df_features.select_dtypes(include=['int64', 'float64']).columns.tolist()
cat_cols = df_features.select_dtypes(include='object').columns.tolist()

# Step 6: Impute missing values
num_imputer = SimpleImputer(strategy='mean')
cat_imputer = SimpleImputer(strategy='most_frequent')

df_features[num_cols] = num_imputer.fit_transform(df_features[num_cols])
df_features[cat_cols] = cat_imputer.fit_transform(df_features[cat_cols])

# Step 7: Create dummy variables
df_encoded = pd.get_dummies(df_features, drop_first=True)

# Step 8: Combine features and target
df_encoded['Attrition'] = target.values

# Step 9: Split into features and target again
X = df_encoded.drop(columns='Attrition')
y = df_encoded['Attrition']

# Step 10: Train-validation split
X_train, X_validation, y_train, y_validation = train_test_split(
    X, y, test_size=0.30, random_state=42, stratify=y
)

# Step 11: Scale numeric features
scaler = StandardScaler()
X_train[num_cols] = scaler.fit_transform(X_train[num_cols])
X_validation[num_cols] = scaler.transform(X_validation[num_cols])

# Final validation
print("✅ Any NaNs in X_train?", X_train.isnull().sum().sum() > 0)
print("✅ Any NaNs in X_validation?", X_validation.isnull().sum().sum() > 0)
print("X_train shape:", X_train.shape)
# Out:
# ✅ Any NaNs in X_train? False
# ✅ Any NaNs in X_validation? False
# X_train shape: (52227, 37)

# %%
# Import RFE and select 15 variables
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# Initialize logistic regression model
logreg = LogisticRegression(random_state=42, max_iter=1000)

# Initialize RFE to select top 15 features
rfe = RFE(estimator=logreg, n_features_to_select=15)

# Fit RFE on the training data
rfe.fit(X_train, y_train)

# Get the names of selected features
selected_features = X_train.columns[rfe.support_].tolist()

# Print the selected features
print("Top 15 selected features using RFE:")
print(selected_features)
# Out:
# Top 15 selected features using RFE:
# ['Gender_Male', 'Work-Life Balance_Fair', 'Work-Life Balance_Poor', 'Job Satisfaction_Low', 'Job Satisfaction_Very High', 'Performance Rating_Below Average', 'Performance Rating_Low', 'Overtime_Yes', 'Education Level_PhD', 'Marital Status_Single', 'Job Level_Mid', 'Job Level_Senior', 'Remote Work_Yes', 'Company Reputation_Fair', 'Company Reputation_Poor']

# %%
# Display the features selected by RFE
# Assuming RFE has been fitted
selected_features = X_train.columns[rfe.support_]

# Display the selected features
print("✅ Features selected by RFE (Top 15):")
for feature in selected_features:
    print("-", feature)
# Out:
# ✅ Features selected by RFE (Top 15):
# - Gender_Male
# - Work-Life Balance_Fair
# - Work-Life Balance_Poor
# - Job Satisfaction_Low
# - Job Satisfaction_Very High
# - Performance Rating_Below Average
# - Performance Rating_Low
# - Overtime_Yes
# - Education Level_PhD
# - Marital Status_Single
# - Job Level_Mid
# - Job Level_Senior
# - Remote Work_Yes
# - Company Reputation_Fair
# - Company Reputation_Poor

# %% [markdown]
# 7.1.3 Store the selected features <font color="red">[1 Mark]</font>

# %%
# Put columns selected by RFE into variable 'col'
# Store selected features into 'col'
col = X_train.columns[rfe.support_].tolist()

# Optional: View the variable
print("Columns selected by RFE:")
print(col)
# Out:
# Columns selected by RFE:
# ['Gender_Male', 'Work-Life Balance_Fair', 'Work-Life Balance_Poor', 'Job Satisfaction_Low', 'Job Satisfaction_Very High', 'Performance Rating_Below Average', 'Performance Rating_Low', 'Overtime_Yes', 'Education Level_PhD', 'Marital Status_Single', 'Job Level_Mid', 'Job Level_Senior', 'Remote Work_Yes', 'Company Reputation_Fair', 'Company Reputation_Poor']

# %% [markdown]
# ### **7.2 Building Logistic Regression Model** <font color = red>[20 marks]</font>
#
# Now that you have selected the variables through RFE, use these features to build a logistic regression model with statsmodels. This will allow you to assess the statistical aspects, such as p-values and VIFs, which are important for checking multicollinearity and ensuring that the predictors are not highly correlated with each other, as this could distort the model's coefficients.

# %% [markdown]
# 7.2.1 Select relevant columns on training set <font color="red">[1 Mark]</font>

# %%
# Select only the columns selected by RFE

# Filter X_train and X_validation to only keep RFE-selected features
X_train_selected = X_train[col]
X_validation_selected = X_validation[col]

# Confirm shapes
print("Shape of X_train_selected:", X_train_selected.shape)
print("Shape of X_validation_selected:", X_validation_selected.shape)
# Out:
# Shape of X_train_selected: (52227, 15)
# Shape of X_validation_selected: (22383, 15)

# %%
# View the training data
# Display the first few rows of the training data with selected features
print("Training data with selected RFE features:")
print(X_train_selected.head())
# Out:
# Training data with selected RFE features:
#        Gender_Male  Work-Life Balance_Fair  Work-Life Balance_Poor  \
# 51296         True                    True                   False
# 33235        False                    True                   False
# 68657         True                   False                   False
# 65440         True                   False                   False
# 24867        False                   False                   False
#
#        Job Satisfaction_Low  Job Satisfaction_Very High  \
# 51296                 False                       False
# 33235                 False                       False
# 68657                 False                       False
# 65440                 False                       False
# 24867                 False                        True
#
#        Performance Rating_Below Average  Performance Rating_Low  Overtime_Yes  \
# 51296                             False                   False         False
# ...

# %% [markdown]
# 7.2.2 Add constant to training set <font color = "red">[1 Mark]</font>

# %%
# Import statsmodels and add constant to training set
import statsmodels.api as sm

# Add a constant to the training data
X_train_sm = sm.add_constant(X_train_selected)

# Display first few rows to confirm
print(X_train_sm.head())
# Out:
#        const  Gender_Male  Work-Life Balance_Fair  Work-Life Balance_Poor  \
# 51296    1.0         True                    True                   False
# 33235    1.0        False                    True                   False
# 68657    1.0         True                   False                   False
# 65440    1.0         True                   False                   False
# 24867    1.0        False                   False                   False
#
#        Job Satisfaction_Low  Job Satisfaction_Very High  \
# 51296                 False                       False
# 33235                 False                       False
# 68657                 False                       False
# 65440                 False                       False
# 24867                 False                        True
#
#        Performance Rating_Below Average  Performance Rating_Low  Overtime_Yes  \
# 51296                             False                   False         False
# ...

# %% [markdown]
# 7.2.3 Fit logistic regression model <font color="red">[3 Marks]</font>

# %%
import statsmodels.api as sm

# Add constant
X_train_sm = sm.add_constant(X_train_selected)

# Force all object columns to numeric (float)
X_train_sm = X_train_sm.astype(float)

# Now fit the model
logit_model = sm.Logit(y_train, X_train_sm)
result = logit_model.fit()

# Print summary
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.506705
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:              Attrition   No. Observations:                52227
# Model:                          Logit   Df Residuals:                    52211
# Method:                           MLE   Df Model:                           15
# Date:                Sat, 19 Apr 2025   Pseudo R-squ.:                  0.2676
# Time:                        20:06:57   Log-Likelihood:                -26464.
# converged:                       True   LL-Null:                       -36134.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %%
# Fit a logistic regression model on X_train after adding a constant and output the summary
import statsmodels.api as sm
# Step 1: Add constant to X_train (if not already done)
X_train_sm = sm.add_constant(X_train_selected).astype(float)

# Step 2: Fit the logistic regression model
logit_model = sm.Logit(y_train, X_train_sm)
result = logit_model.fit()

# Step 3: Output the model summary
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.506705
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:              Attrition   No. Observations:                52227
# Model:                          Logit   Df Residuals:                    52211
# Method:                           MLE   Df Model:                           15
# Date:                Sat, 19 Apr 2025   Pseudo R-squ.:                  0.2676
# Time:                        20:06:58   Log-Likelihood:                -26464.
# converged:                       True   LL-Null:                       -36134.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# **Model Interpretation**
#
# The output summary table  will provide the features used for building model along with coefficient of each of the feature and their p-value. The p-value in a logistic regression model is used to assess the statistical significance of each coefficient. Lesser the p-value, more significant the feature is in the model.
#
# A positive coefficient will indicate that an increase in the value of feature would increase the odds of the event occurring. On the other hand, a negative coefficient means the opposite, i.e,  an increase in the value of feature would decrease the odds of the event occurring.

# %% [markdown]
# 7.2.4 Evaluate VIF of features <font color="red">[3 Marks]</font>

# %%
# Import 'variance_inflation_factor'
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Make a VIF DataFrame for all the variables present

# Step 1: Add constant (if not already added)
X_vif = sm.add_constant(X_train_selected).astype(float)

# Step 2: Create VIF DataFrame
vif_data = pd.DataFrame()
vif_data["Feature"] = X_vif.columns
vif_data["VIF"] = [variance_inflation_factor(X_vif.values, i) for i in range(X_vif.shape[1])]

# Step 3: Display the VIF DataFrame
print(vif_data)
# Out:
#                              Feature       VIF
# 0                              const  7.199226
# 1                        Gender_Male  1.000486
# 2             Work-Life Balance_Fair  1.074910
# 3             Work-Life Balance_Poor  1.074843
# 4               Job Satisfaction_Low  1.029187
# 5         Job Satisfaction_Very High  1.029152
# 6   Performance Rating_Below Average  1.009422
# 7             Performance Rating_Low  1.009885
# 8                       Overtime_Yes  1.000523
# 9                Education Level_PhD  1.000306
# 10             Marital Status_Single  1.000278
# 11                     Job Level_Mid  1.201914
# 12                  Job Level_Senior  1.201781
# 13                   Remote Work_Yes  1.000329
# 14           Company Reputation_Fair  1.067968
# 15           Company Reputation_Poor  1.068062

# %% [markdown]
# Proceed to the next step if p-values and VIFs are within acceptable ranges.  If you observe high p-values or VIFs, create new cells to drop the features and retrain the model.

# %% [markdown]
# 7.2.5 Make predictions on training set <font color = "red">[2 Marks]</font>

# %%
# Predict the probabilities on the training set
# Step 1: Add constant to X_train (if not already done)
X_train_sm = sm.add_constant(X_train_selected).astype(float)

# Step 2: Predict probabilities using the fitted model
y_train_pred_prob = result.predict(X_train_sm)

# Step 3: View first few predicted probabilities
print("Predicted probabilities on training set:")
print(y_train_pred_prob.head())
# Out:
# Predicted probabilities on training set:
# 51296    0.680348
# 33235    0.963770
# 68657    0.267686
# 65440    0.460592
# 24867    0.180086
# dtype: float64

# %% [markdown]
# 7.2.6 Format the prediction output <font color="red">[1 Mark]</font>

# %%
# Reshape it into an array

# Reshape into a 2D array (column vector)
y_train_pred_prob_array = np.array(y_train_pred_prob).reshape(-1, 1)

# Check the shape
print("Reshaped array shape:", y_train_pred_prob_array.shape)
# Out:
# Reshaped array shape: (52227, 1)

# %% [markdown]
# 7.2.7 Create a DataFrame with the actual stayed flag and the predicted probabilities <font color="red">[1 Mark]</font>

# %%
# Create a new DataFrame containing the actual stayed flag and the probabilities predicted by the model

y_train_pred_prob_array = np.array(y_train_pred_prob).reshape(-1, 1)

# Create a DataFrame
comparison_df = pd.DataFrame({
    'Actual_Attrition': y_train.values,
    'Predicted_Probability': y_train_pred_prob_array.flatten()
})

# Show first few rows
print(comparison_df.head())
# Out:
#    Actual_Attrition  Predicted_Probability
# 0                 1               0.680348
# 1                 1               0.963770
# 2                 0               0.267686
# 3                 1               0.460592
# 4                 0               0.180086

# %% [markdown]
# 7.2.8 Create a new column 'Predicted' with 1 if predicted probabilities are greater than 0.5 else 0 <font color = "red">[1 Mark]</font>

# %%
# Create a new column 'Predicted' with 1 if predicted probabilities are greater than 0.5 else 0
# Add 'Predicted' column based on 0.5 threshold
comparison_df['Predicted'] = (comparison_df['Predicted_Probability'] >= 0.5).astype(int)

# Preview the updated DataFrame
print(comparison_df.head())
# Out:
#    Actual_Attrition  Predicted_Probability  Predicted
# 0                 1               0.680348          1
# 1                 1               0.963770          1
# 2                 0               0.267686          0
# 3                 1               0.460592          0
# 4                 0               0.180086          0

# %% [markdown]
# **Evaluation of performance of Model**
#
# Evaluate the performance of the model based on the predictions made on the training set.

# %% [markdown]
# 7.2.9 Check the accuracy of the model based on the predictions made on the training set <font color = "red">[1 Mark]</font>

# %%
# Import metrics from sklearn for evaluation
from sklearn import metrics

# Calculate accuracy using actual vs predicted values
accuracy = metrics.accuracy_score(comparison_df['Actual_Attrition'], comparison_df['Predicted'])

# Print the accuracy
print(" Overall Accuracy of the Model:", round(accuracy, 4))
# Out:
#  Overall Accuracy of the Model: 0.7399

# %% [markdown]
# 7.2.10 Create a confusion matrix based on the predictions made on the training set <font color="red">[1 mark]</font>

# %%
# Create confusion matrix
from sklearn.metrics import confusion_matrix

# Generate the confusion matrix
conf_matrix = confusion_matrix(comparison_df['Actual_Attrition'], comparison_df['Predicted'])

# Display the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[20768  6666]
#  [ 6917 17876]]

# %% [markdown]
# 7.2.11 Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
# Extract values from confusion matrix
tn, fp, fn, tp = conf_matrix.ravel()

# Assign to variables
true_positive = tp
true_negative = tn
false_positive = fp
false_negative = fn

# Print the results
print(f"True Positive: {true_positive}")
print(f"True Negative: {true_negative}")
print(f"False Positive: {false_positive}")
print(f"False Negative: {false_negative}")
# Out:
# True Positive: 17876
# True Negative: 20768
# False Positive: 6666
# False Negative: 6917

# %% [markdown]
# 7.2.12 Calculate sensitivity and specificity of model  <font color="red">[2 Marks]</font>

# %%
# Calculate sensitivity
# Calculate sensitivity (recall)
sensitivity = true_positive / (true_positive + false_negative)

# Display the result
print(f"Sensitivity (Recall): {sensitivity:.2%}")
# Out:
# Sensitivity (Recall): 72.10%

# %%
# Calculate specificity
# Calculate specificity
specificity = true_negative / (true_negative + false_positive)

# Display the result
print(f"Specificity: {specificity:.2%}")
# Out:
# Specificity: 75.70%

# %% [markdown]
# 7.2.13 Calculate precision and recall of model <font color="red">[2 Marks]</font>

# %%
# Calculate precision
# Calculate precision
precision = true_positive / (true_positive + false_positive)

# Display the result
print(f"Precision: {precision:.2%}")
# Out:
# Precision: 72.84%

# %%
# Calculate recall
# Calculate recall (same as sensitivity)
recall = true_positive / (true_positive + false_negative)

# Display the result
print(f"Recall: {recall:.2%}")
# Out:
# Recall: 72.10%

# %% [markdown]
# ### **7.3 Find the optimal cutoff** <font color = red>[15 marks]</font>
#
# Find the optimal cutoff to improve model performance. While a default threshold of 0.5 was used for initial evaluation, optimising this threshold can enhance the model's performance.
#
# First, plot the ROC curve and check AUC.

# %% [markdown]
# 7.3.1 Plot ROC curve <font color="red">[3 Marks]</font>

# %%
# Define ROC function
def plot_roc_curve(y_true, y_pred_prob, title='ROC Curve'):
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    auc = roc_auc_score(y_true, y_pred_prob)

    plt.figure(figsize=(6, 5))
    plt.plot(fpr, tpr, label=f'AUC = {auc:.2f}')
    plt.plot([0, 1], [0, 1], linestyle='--', color='gray')  # Diagonal line
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate (Recall)')
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    print(f"AUC Score: {auc:.2f}")

# %%
# Call the ROC function
from sklearn.metrics import roc_curve, roc_auc_score
train_results = pd.DataFrame({
    'Actual_Attrition': y_train.values,
    'Predicted_Probability': y_train_pred_prob
})
# Call the ROC function on training set
plot_roc_curve(train_results['Actual_Attrition'], train_results['Predicted_Probability'], title='ROC Curve - Training Set')
# Out:
# AUC Score: 0.83

# %% [markdown]
# **Sensitivity and Specificity tradeoff**
#
# Check sensitivity and specificity tradeoff to find the optimal cutoff point.

# %% [markdown]
# 7.3.2 Predict on training set at various probability cutoffs <font color="red">[1 Mark]</font>

# %%
# Predict on training data by creating columns with different probability cutoffs to explore the impact of cutoff on model performance
# Define a list of cutoff values to evaluate
cutoff_values = [round(x * 0.1, 2) for x in range(1, 10)]  # 0.1 to 0.9

# Initialize a list to store results
cutoff_analysis = []

# Loop through different cutoff values
for cutoff in cutoff_values:
    predicted = train_results['Predicted_Probability'].apply(lambda x: 1 if x > cutoff else 0)
    tn, fp, fn, tp = metrics.confusion_matrix(train_results['Actual_Attrition'], predicted).ravel()
    
    # Calculate sensitivity and specificity
    sensitivity = tp / (tp + fn) if (tp + fn) != 0 else 0
    specificity = tn / (tn + fp) if (tn + fp) != 0 else 0
    
    cutoff_analysis.append([cutoff, sensitivity, specificity])

# Convert to DataFrame
cutoff_df = pd.DataFrame(cutoff_analysis, columns=['Cutoff', 'Sensitivity', 'Specificity'])

# Display the cutoff analysis
print(cutoff_df)
# Out:
#    Cutoff  Sensitivity  Specificity
# 0     0.1     0.991691     0.220857
# 1     0.2     0.954705     0.392506
# 2     0.3     0.899488     0.526281
# 3     0.4     0.819304     0.649741
# 4     0.5     0.721010     0.757017
# 5     0.6     0.607793     0.842240
# 6     0.7     0.477917     0.909565
# 7     0.8     0.320453     0.963840
# 8     0.9     0.143710     0.995079

# %% [markdown]
# 7.3.3 Plot for accuracy, sensitivity, specificity at different probability cutoffs <font color="red">[2 Marks]</font>

# %%
# Create a DataFrame to see the values of accuracy, sensitivity, and specificity at different values of probability cutoffs
# Define a list of cutoff values to evaluate
cutoff_values = [round(x * 0.05, 2) for x in range(1, 20)]  # 0.05 to 0.95

# Initialize a list to store results
cutoff_analysis = []

# Loop through different cutoff values
for cutoff in cutoff_values:
    predicted = train_results['Predicted_Probability'].apply(lambda x: 1 if x > cutoff else 0)
    
    # Confusion matrix
    tn, fp, fn, tp = metrics.confusion_matrix(train_results['Actual_Attrition'], predicted).ravel()
    
    # Calculate metrics
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    sensitivity = tp / (tp + fn) if (tp + fn) != 0 else 0
    specificity = tn / (tn + fp) if (tn + fp) != 0 else 0
    
    # Append to list
    cutoff_analysis.append([cutoff, accuracy, sensitivity, specificity])

# Convert to DataFrame
cutoff_df = pd.DataFrame(cutoff_analysis, columns=['Cutoff', 'Accuracy', 'Sensitivity', 'Specificity'])

# Display the DataFrame
print(cutoff_df)
# Out:
#     Cutoff  Accuracy  Sensitivity  Specificity
# 0     0.05  0.525916     0.999476     0.097944
# 1     0.10  0.586785     0.991691     0.220857
# 2     0.15  0.630995     0.974912     0.320187
# 3     0.20  0.659391     0.954705     0.392506
# 4     0.25  0.686963     0.922075     0.474484
# 5     0.30  0.703448     0.899488     0.526281
# 6     0.35  0.722710     0.852700     0.605234
# 7     0.40  0.730235     0.819304     0.649741
# 8     0.45  0.737607     0.763683     0.714041
# 9     0.50  0.739924     0.721010     0.757017
# 10    0.55  0.739541     0.678296     0.794890
# 11    0.60  0.730944     0.607793     0.842240
# 12    0.65  0.720087     0.545154     0.878180
# 13    0.70  0.704655     0.477917     0.909565
# 14    0.75  0.684608     0.402130     0.939892
# 15    0.80  0.658414     0.320453     0.963840
# 16    0.85  0.629004     0.237930     0.982431
# 17    0.90  0.590920     0.143710     0.995079
# 18    0.95  0.546269     0.044892     0.999380

# %%
# Plot accuracy, sensitivity, and specificity at different values of probability cutoffs

plt.figure(figsize=(10, 6))
plt.plot(cutoff_df['Cutoff'], cutoff_df['Accuracy'], label='Accuracy', marker='o')
plt.plot(cutoff_df['Cutoff'], cutoff_df['Sensitivity'], label='Sensitivity', marker='o')
plt.plot(cutoff_df['Cutoff'], cutoff_df['Specificity'], label='Specificity', marker='o')

# Add labels and title
plt.xlabel('Probability Cutoff')
plt.ylabel('Score')
plt.title('Accuracy, Sensitivity, and Specificity vs Probability Cutoff')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 7.3.4 Create a column for final prediction based on the optimal cutoff <font color="red">[2 Marks]</font>

# %%
# Create a column for final prediction based on the optimal cutoff
# Define your optimal cutoff (example: 0.45)
optimal_cutoff = 0.45

# Create a new column 'Final_Prediction' based on the chosen cutoff
train_results['Final_Prediction'] = train_results['Predicted_Probability'].apply(lambda x: 1 if x > optimal_cutoff else 0)

# Display the updated DataFrame
print(train_results[['Actual_Attrition', 'Predicted_Probability', 'Final_Prediction']].head())
# Out:
#        Actual_Attrition  Predicted_Probability  Final_Prediction
# 51296                 1               0.680348                 1
# 33235                 1               0.963770                 1
# 68657                 0               0.267686                 0
# 65440                 1               0.460592                 1
# 24867                 0               0.180086                 0

# %% [markdown]
# 7.3.5 Calculate model's accuracy <font color="red">[1Mark]</font>

# %%
# Calculate the accuracy
from sklearn.metrics import accuracy_score

# Calculate accuracy using final predictions
final_accuracy = accuracy_score(train_results['Actual_Attrition'], train_results['Final_Prediction'])

# Display the result
print(f"Final Accuracy (based on optimal cutoff): {final_accuracy:.2%}")
# Out:
# Final Accuracy (based on optimal cutoff): 73.76%

# %% [markdown]
# 7.3.6 Create confusion matrix <font color="red">[1Mark]</font>

# %%
# Create the confusion matrix once again
from sklearn.metrics import confusion_matrix

# Generate confusion matrix using final predictions
final_conf_matrix = confusion_matrix(train_results['Actual_Attrition'], train_results['Final_Prediction'])

# Display the confusion matrix
print("Confusion Matrix (Final Prediction):")
print(final_conf_matrix)
# Out:
# Confusion Matrix (Final Prediction):
# [[19589  7845]
#  [ 5859 18934]]

# %% [markdown]
# 7.3.7 Create variables for true positive, true negative, false positive and false negative <font color="red">[1Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
# Unpack the values from the confusion matrix
tn, fp, fn, tp = final_conf_matrix.ravel()

# Assign to readable variable names
true_positive = tp
true_negative = tn
false_positive = fp
false_negative = fn

# Display the values
print(f"True Positive: {true_positive}")
print(f"True Negative: {true_negative}")
print(f"False Positive: {false_positive}")
print(f"False Negative: {false_negative}")
# Out:
# True Positive: 18934
# True Negative: 19589
# False Positive: 7845
# False Negative: 5859

# %% [markdown]
# 7.3.8 Calculate sensitivity and specificity of the model <font color="red">[1Mark]</font>

# %%
# Calculate Sensitivity
# Calculate Sensitivity (Recall)
final_sensitivity = true_positive / (true_positive + false_negative)

# Display the result
print(f"Final Sensitivity (Recall): {final_sensitivity:.2%}")
# Out:
# Final Sensitivity (Recall): 76.37%

# %%
# Calculate Specificity

final_specificity = tn / (tn + fp)

# Print result
print(f"Final specificity: {final_specificity:.2%}")
# Out:
# Final specificity: 71.40%

# %% [markdown]
# 7.3.9 Calculate precision and recall of the model <font color="red">[1Mark]</font>

# %%
# Calculate Precision
# Calculate Specificity
final_specificity = true_negative / (true_negative + false_positive)

# Display the result
print(f"Final Specificity: {final_specificity:.2%}")
# Out:
# Final Specificity: 71.40%

# %%
# Calculate Recall
# Calculate Recall
final_recall = true_positive / (true_positive + false_negative)

# Display the result
print(f"Final Recall: {final_recall:.2%}")
# Out:
# Final Recall: 76.37%

# %% [markdown]
# **Precision and Recall tradeoff**
#
# Check optimal cutoff value by plotting precision-recall curve, and adjust the cutoff based on the precision and recall tradeoff if required.

# %%
# Import precision-recall curve function
from sklearn.metrics import precision_recall_curve

# %%
# Check actual and predicted values from initial model
# Display actual vs predicted values from the model
print(train_results[['Actual_Attrition', 'Predicted_Probability', 'Final_Prediction']].head())
# Out:
#        Actual_Attrition  Predicted_Probability  Final_Prediction
# 51296                 1               0.680348                 1
# 33235                 1               0.963770                 1
# 68657                 0               0.267686                 0
# 65440                 1               0.460592                 1
# 24867                 0               0.180086                 0

# %% [markdown]
# 7.3.10 Plot precision-recall curve <font color="red">[2 Marks]</font>

# %%
# Plot precision-recall curve
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

# Get precision, recall, and thresholds
precision, recall, thresholds = precision_recall_curve(train_results['Actual_Attrition'], train_results['Predicted_Probability'])

# Plot the precision-recall curve
plt.figure(figsize=(8, 5))
plt.plot(thresholds, precision[:-1], label='Precision', marker='.')
plt.plot(thresholds, recall[:-1], label='Recall', marker='.')
plt.xlabel('Probability Threshold')
plt.ylabel('Score')
plt.title('Precision-Recall Tradeoff')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **8. Prediction and Model Evaluation** <font color = red>[30 marks]</font>
#
# Use the model from the previous step to make predictions on the validation set with the optimal cutoff. Then evaluate the model's performance using metrics such as accuracy, sensitivity, specificity, precision, and recall.

# %% [markdown]
# ### **8.1 Make predictions over validation set** <font color = red>[15 marks]</font>

# %% [markdown]
# 8.1.1 Select relevant features for validation set <font color="red">[2 Marks]</font>

# %%
# Select the relevant features for validation set
# Convert scaled validation set back to a DataFrame
# Select only RFE-selected features from validation set
X_validation_selected = X_validation[col]

# Preview the selected validation data
print("Validation set with selected features:")
print(X_validation_selected.head())
# Out:
# Validation set with selected features:
#        Gender_Male  Work-Life Balance_Fair  Work-Life Balance_Poor  \
# 32547         True                   False                   False
# 71370         True                   False                   False
# 65857        False                   False                   False
# 45389         True                   False                   False
# 33792        False                    True                   False
#
#        Job Satisfaction_Low  Job Satisfaction_Very High  \
# 32547                 False                       False
# 71370                 False                        True
# 65857                 False                       False
# 45389                 False                        True
# 33792                 False                       False
#
#        Performance Rating_Below Average  Performance Rating_Low  Overtime_Yes  \
# 32547                             False                   False         False
# ...

# %% [markdown]
# 8.1.2 Add constant to X_validation <font color="red">[2 Marks]</font>

# %%
# Add constant to X_validation
import statsmodels.api as sm

# Add constant to X_validation_selected
X_validation_sm = sm.add_constant(X_validation_selected).astype(float)

# Preview the result
print(X_validation_sm.head())
# Out:
#        const  Gender_Male  Work-Life Balance_Fair  Work-Life Balance_Poor  \
# 32547    1.0          1.0                     0.0                     0.0
# 71370    1.0          1.0                     0.0                     0.0
# 65857    1.0          0.0                     0.0                     0.0
# 45389    1.0          1.0                     0.0                     0.0
# 33792    1.0          0.0                     1.0                     0.0
#
#        Job Satisfaction_Low  Job Satisfaction_Very High  \
# 32547                   0.0                         0.0
# 71370                   0.0                         1.0
# 65857                   0.0                         0.0
# 45389                   0.0                         1.0
# 33792                   0.0                         0.0
#
#        Performance Rating_Below Average  Performance Rating_Low  Overtime_Yes  \
# 32547                               0.0                     0.0           0.0
# ...

# %% [markdown]
# 8.1.3 Make predictions over validation set <font color="red">[3 Marks]</font>

# %%
# Make predictions on the validation set and store it in the variable 'y_validation_pred'
# Predict probabilities on the validation set
y_validation_pred = result.predict(X_validation_sm)

# View the first few predictions
print("Predicted probabilities on validation set:")
print(y_validation_pred.head())
# Out:
# Predicted probabilities on validation set:
# 32547    0.146788
# 71370    0.417641
# 65857    0.645728
# 45389    0.710410
# 33792    0.472432
# dtype: float64

# %% [markdown]
# 8.1.4 Create DataFrame with actual values and predicted values for validation set <font color="red">[5 Marks]</font>

# %%
# Convert 'y_validation_pred' to a DataFrame 'predicted_probability'
# Step 1: Convert predicted probabilities to DataFrame
predicted_probability = pd.DataFrame(y_validation_pred, columns=['Predicted_Probability'])

# Step 2: Convert actual values to DataFrame
actual = pd.DataFrame(y_validation.values, columns=['Actual_Attrition'])

# Step 3: Reset index for both DataFrames
predicted_probability.reset_index(drop=True, inplace=True)
actual.reset_index(drop=True, inplace=True)

# Step 4: Combine both DataFrames side by side
validation_results = pd.concat([actual, predicted_probability], axis=1)

# Preview the result
print(validation_results.head())
# Out:
#    Actual_Attrition  Predicted_Probability
# 0                 0               0.146788
# 1                 0               0.417641
# 2                 1               0.645728
# 3                 0               0.710410
# 4                 1               0.472432

# %% [markdown]
# 8.1.5 Predict final prediction based on the cutoff value <font color="red">[3 Marks]</font>

# %%
# Make predictions on the validation set using the optimal cutoff and store it in a column 'final_prediction'
# Apply cutoff of 0.5 to predicted probabilities
validation_results['final_prediction'] = (validation_results['Predicted_Probability'] >= 0.5).astype(int)

# View updated DataFrame
print(validation_results.head())
# Out:
#    Actual_Attrition  Predicted_Probability  final_prediction
# 0                 0               0.146788                 0
# 1                 0               0.417641                 0
# 2                 1               0.645728                 1
# 3                 0               0.710410                 1
# 4                 1               0.472432                 0

# %% [markdown]
# ### **8.2 Calculate accuracy of the model** <font color = red>[2 marks]</font>

# %%
# Calculate the overall accuracy
from sklearn.metrics import accuracy_score

# Calculate accuracy
accuracy = accuracy_score(validation_results['Actual_Attrition'], validation_results['final_prediction'])

# Display the result
print("Overall Accuracy on Validation Set:", round(accuracy, 4))
# Out:
# Overall Accuracy on Validation Set: 0.7356

# %% [markdown]
# ### **8.3 Create confusion matrix and create variables for true positive, true negative, false positive and false negative** <font color = red>[5 marks]</font>

# %%
# Create confusion matrix
from sklearn.metrics import confusion_matrix

# Create confusion matrix
conf_matrix = confusion_matrix(validation_results['Actual_Attrition'], validation_results['final_prediction'])

# Display the matrix
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[8827 2930]
#  [2988 7638]]

# %%
# Create variables for true positive, true negative, false positive and false negative

tn, fp, fn, tp = confusion_matrix(
    validation_results['Actual_Attrition'],
    validation_results['final_prediction']
).ravel()

true_positive_val = tp
false_negative_val = fn
true_negative_val = tn
false_positive_val = fp
# Display each value
print(f"✅ True Negatives (TN): {tn}")
print(f"✅ False Positives (FP): {fp}")
print(f"✅ False Negatives (FN): {fn}")
print(f"✅ True Positives (TP): {tp}")
# Out:
# ✅ True Negatives (TN): 8827
# ✅ False Positives (FP): 2930
# ✅ False Negatives (FN): 2988
# ✅ True Positives (TP): 7638

# %% [markdown]
# ### **8.4 Calculate sensitivity and specificity** <font color = red>[4 marks]</font>

# %%
# Calculate sensitivity
# Calculate sensitivity for the validation set
sensitivity_val = true_positive_val / (true_positive_val + false_negative_val)

# Display the result
print(f"Validation Sensitivity (Recall): {sensitivity_val:.2%}")
# Out:
# Validation Sensitivity (Recall): 71.88%

# %%
# Calculate specificity
# Calculate specificity for the validation set
specificity_val = true_negative_val / (true_negative_val + false_positive_val)

# Display the result
print(f"Validation Specificity: {specificity_val:.2%}")
# Out:
# Validation Specificity: 75.08%

# %% [markdown]
# ### **8.5 Calculate precision and recall** <font color = red>[4 marks]</font>

# %%
# Calculate precision
# Calculate precision for the validation set
precision_val = true_positive_val / (true_positive_val + false_positive_val)

# Display the result
print(f"Validation Precision: {precision_val:.2%}")
# Out:
# Validation Precision: 72.27%

# %%
# Calculate recall
# Calculate recall for the validation set
recall_val = true_positive_val / (true_positive_val + false_negative_val)

# Display the result
print(f"Validation Recall: {recall_val:.2%}")
# Out:
# Validation Recall: 71.88%

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The model gives HR actionable insights into key risk factors for attrition.
#
# With a solid accuracy range of 70 to 80%, it can be used to proactively identify at-risk employees.
#
# HR can now tailor retention strategies for employees with high predicted attrition risk  especially those who are:
#
# Single
#
# Experiencing poor work-life balance
#
# Working onsite without remote flexibility
#
# In junior roles
